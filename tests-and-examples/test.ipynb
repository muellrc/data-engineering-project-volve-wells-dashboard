# %%
import psycopg2

# establishing the connection
conn = psycopg2.connect(
    database="postgres", user='postgres', password='dev-postgres-db', host='127.0.0.1', port='5432'
)
# Creating a cursor object using the cursor() method
cursor = conn.cursor()

# Executing an MYSQL function using the execute() method
cursor.execute("select version()")

# Fetch a single row using fetchone() method.
data = cursor.fetchone()
print("Connection established to: ", data)

# Closing the connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/christianmueller/Library/Mobile Documents/com~apple~CloudDocs/Studies/Academic/5. MSc CS/2022/2022.1/7. DLMDSEDE02 Project Data Engineering/4. Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb Cell 1' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/christianmueller/Library/Mobile%20Documents/com~apple~CloudDocs/Studies/Academic/5.%20MSc%20CS/2022/2022.1/7.%20DLMDSEDE02%20Project%20Data%20Engineering/4.%20Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb#ch0000000?line=0'>1</a> import psycopg2
#       <a href='vscode-notebook-cell:/Users/christianmueller/Library/Mobile%20Documents/com~apple~CloudDocs/Studies/Academic/5.%20MSc%20CS/2022/2022.1/7.%20DLMDSEDE02%20Project%20Data%20Engineering/4.%20Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb#ch0000000?line=2'>3</a> # establishing the connection
#       <a href='vscode-notebook-cell:/Users/christianmueller/Library/Mobile%20Documents/com~apple~CloudDocs/Studies/Academic/5.%20MSc%20CS/2022/2022.1/7.%20DLMDSEDE02%20Project%20Data%20Engineering/4.%20Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb#ch0000000?line=3'>4</a> conn = psycopg2.connect(
#       <a href='vscode-notebook-cell:/Users/christianmueller/Library/Mobile%20Documents/com~apple~CloudDocs/Studies/Academic/5.%20MSc%20CS/2022/2022.1/7.%20DLMDSEDE02%20Project%20Data%20Engineering/4.%20Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb#ch0000000?line=4'>5</a>     database="postgres", user='postgres', password='dev-postgres-db', host='127.0.0.1', port='5432'
#       <a href='vscode-notebook-cell:/Users/christianmueller/Library/Mobile%20Documents/com~apple~CloudDocs/Studies/Academic/5.%20MSc%20CS/2022/2022.1/7.%20DLMDSEDE02%20Project%20Data%20Engineering/4.%20Assignments/Deliverables/DLMDSEDE02-project-cmueller/postgres/test.ipynb#ch0000000?line=5'>6</a> )
#
# ModuleNotFoundError: No module named 'psycopg2'
